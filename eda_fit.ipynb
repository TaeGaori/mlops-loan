# %% [markdown]
# # EDA 및 전처리

# %% [markdown]
# ## 라이브러리 불러오기

# %%
import pandas as pd
import numpy as np
import warnings
import joblib
import os
# Out:
# 'mlops-loan (3.10.x) (Python 3.10.-1)'(으)로 셀을 실행하려면 ipykernel 패키지가 필요합니다.
#
# 'ipykernel'을(를) Python 환경에 설치합니다.
#
# 명령: 'c:/Users/Administrator/mlops-loan/.venv/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'
